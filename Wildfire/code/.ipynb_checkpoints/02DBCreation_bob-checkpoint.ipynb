# %% [markdown]
# This code is adapted from group member Juhee Sung-Schenck

# %%
# import libraries

import pandas as pd
import numpy as np
import math
from numpy import random

import plotly.express as px
import plotly.offline as pyo
import plotly.graph_objs as go

# %%
# read in the data

eq = pd.read_csv('../data/wildfire_new.csv')

# %%
# check for null values - geocode not available for all tweets

eq.isnull().sum()
# Out:
# Unnamed: 0        0
# id                0
# text              8
# keyword        7819
# user_name         0
# date              0
# location      10000
# dtype: int64

# %%
# create a function to generate coordinates within given radius
# this code is my adaptation of Haversine formula
# Bob's genius brain has been input here

def get_coordinates(num, center, radius):
        
    lat, long = center
    
    # add randomness to generate latitude and longitude within the given radius
    rho = np.sqrt(np.random.uniform(0, 1, num))
    phi = np.random.uniform(0, 2 * np.pi, num)
    
    dx = rho * radius * np.cos(phi)
    dy = rho * radius * np.sin(phi)

    # create an empty list to store generated coordinates 
    coordinates = []
    
    for i in range(num):
        
        coordinate = {}
        
        # earth's mean radius is 6371 km
        new_lat = lat + ((180 / math.pi) * (dy[i] / 6371) / math.sin(lat * math.pi / 180)) 
        new_long = long + ((180 / math.pi) * (dx[i] / 6371) / math.cos(long * math.pi / 180))
        
        coordinate['lat'] = new_lat
        coordinate['long'] = new_long
        
        # add to list
        coordinates.append(coordinate)

    return coordinates

# %%
coordinates = get_coordinates(len(eq['location']), (36.7378, -119.7871), 150) # --> radius of collected tweets from the center

# %%
# create columns to store latitude and longitude separately

eq['lat'] = [coordinate['lat'] for coordinate in coordinates]
eq['long'] = [coordinate['long'] for coordinate in coordinates]

# %%
eq.head()
# Out:
#    Unnamed: 0                   id  \
# 0           0  1303845642016497664
# 1           1  1304359517552095235
# 2           2  1303845637851471872
# 3           3  1303845628544520193
# 4           4  1303845625713188865
#
#                                                 text keyword        user_name  \
# 0  Oregon governor says towns have been ‘substant...     NaN  maxwell18191708
# 1  96% Overwhelmingly Positive Reviews! Grab a fr...     NaN     JoinDeepRock
# 2  ‘Catastrophic’ wildfires may be deadliest in O...     NaN      SayWHARadio
# 3  SFGate: Thick wildfire smoke blocks sun, turns...     NaN          rankstr
# 4  Still having a hard time processing that I had...     NaN        zach_wilk
#
#                         date  location        lat        long
# 0  2020-09-09 23:59:59+00:00       NaN  38.161325 -119.138829
# 1  2020-09-11 10:01:57+00:00       NaN  37.226587 -117.574184
# 2  2020-09-09 23:59:59+00:00       NaN  37.850144 -118.243566
# 3  2020-09-09 23:59:56+00:00       NaN  38.383357 -119.384293
# 4  2020-09-09 23:59:56+00:00       NaN  38.534846 -121.127199

# %%
# check the coordinates

fig = px.scatter_mapbox(eq, lat = 'lat', lon = 'long',
                        color_discrete_sequence = ['navy'], zoom = 1, height = 500)
fig.update_layout(mapbox_style = 'open-street-map')
fig.update_layout(margin = {'r': 0, 't': 0, 'l': 0, 'b':0})

fig.write_html('../images/test-fig2.html')
fig.show()
# Out:
# <div>
#
#
#             <div id="3be14f8a-737c-4dd1-b7ac-39e7da0f571b" class="plotly-graph-div" style="height:500px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3be14f8a-737c-4dd1-b7ac-39e7da0f571b")) {
#                     Plotly.newPlot(
#                         '3be14f8a-737c-4dd1-b7ac-39e7da0f571b',
#                         [{"hovertemplate": "lat=%{lat}<br>long=%{lon}<extra></extra>", "lat": [38.16132453090687, 37.22658681171169, 37.85014354294088, 38.38335656603496, 38.534846464499154, 34.889721174080954, 37.221770644389, 36.30267672598964, 35.814220370428444, 35.5756526490966, 35.49739103278482, 35.90981150206683, 37.55696697974654, 36.185014516841726, 38.06825102877899, 35.77358129346354, 38.232206996844916, 35.42966551477373, 36.066361349040655, 35.79946131179549, 36.882797908491845, 35.56593027621354, 37.03812669276414, 38.519975291017964, 36.425518071480646, 36.11198909048717, 36.0158224886242, 37.88326593189843, 38.41644499792083, 37.849262219246214, 35.57781874921619, 37.83170155253744, 38.70142326063595, 37.17320214541715, 38.136722180226286, 35.26628066851524, 35.51317722919194, 38.35803736360324, 36.7529938337552, 38.050109741647155, 37.952349390604894, 35.55332611030889, 36.265143255656426, 36.52492727170049, 35.441505299890025, 36.41028687995528, 35.61570216314133, 36.04473836939681, 37.37199518367627, 37.51497306840287, 36.6154723338678, 34.54964729405392, 37.909597016576804, 36.169977521113495, 37.61371780923529, 35.34140261110425, 36.470303055356716, 37.060977446252494, 37.30786536625244, 35.73140174733893, 37.910429275465226, 38.005159754705005, 36.47948054225299, 38.75162992803103, 38.56023207191854, 35.59695895077148, 34.67965259798934, 36.48912713357138, 37.87584065444931, 36.43259084812883, 36.420218559353316, 37.56029212928808, 36.68361203830504, 38.675686907846064, 34.814116419666554, 37.76743091343423, 37.93246261181267, 36.875923560724985, 38.69306925420505, 35.0571811794394, 36.032614097981664, 35.517533530373356, 37.93086313083213, 36.786350746859966, 36.49990084014881, 37.06737539604715, 37.31788945981787, 37.322261144496366, 38.04713722099267, 35.838056263773396, 34.6699158481865, 36.22622384743398, 35.252481582315504, 34.82182391313079, 36.97689410541602, 35.83126731777606, 34.56267700038867, 34.66741681971105, 36.22663878149142, 34.871014162011555, 34.971345379240134, 37.264700724172954, 37.9126540334296, 37.015492850246225, 35.625008713194546, 36.90698233715514, 38.501640803059715, 35.2591189775644, 38.50622009546569, 35.52805755210478, 36.42373556026428, 38.22615740234197, 36.707340046464644, 37.89262086054939, 37.16233230278636, 34.90224970551774, 36.40924470227219, 35.41952289868122, 34.57016258375776, 35.39210092621744, 38.83209498737193, 38.02390235531828, 36.299651195045136, 38.23242724267078, 37.2995887930884, 37.61341836212704, 38.398789089550675, 36.72709932939159, 35.73541600070403, 35.03686941835797, 36.8232170769565, 36.832109535526676, 37.87706772419429, 35.89863222170671, 38.37022853806182, 38.34349995006624, 36.98496957875945, 37.77636999015526, 35.50690797707764, 35.55883465184788, 38.087722436839584, 37.22769408627058, 35.57931112035286, 36.047954471167415, 35.61226995754076, 37.28925397426581, 36.24128938391967, 37.03104174052654, 37.44285080118172, 35.76580465653775, 38.451523330551346, 37.16137728882964, 36.59835019967629, 35.98083159963316, 38.42073053804168, 36.666339807090246, 35.69075557057397, 36.052697436350975, 36.31664051966797, 36.616281253589214, 36.3261330409223, 37.50434918299, 36.900010593499054, 36.26149444924926, 37.26733524421261, 36.028904982169934, 35.53204395938506, 36.702260590669255, 37.249171361744644, 38.25001076004088, 38.367339462915325, 35.12584209578265, 38.32187915002308, 37.439992020526155, 37.26784110420711, 37.03421778121976, 34.7545243061854, 35.901453792531676, 35.77780695123582, 36.889034115055296, 37.465323138221734, 34.62355608320762, 35.20546072164236, 37.56313563854585, 36.0741231265477, 34.896927503166275, 36.961840969302386, 35.38569643379436, 38.42980592952071, 35.4298508960888, 38.60552049066015, 36.99200105204226, 35.722730147554444, 36.96549941369029, 35.7814431795705, 38.46015355763616, 38.47578131748948, 38.37526151254308, 37.702712373318924, 35.78318129008887, 38.783668917797634, 36.86013261057192, 38.06403867226934, 37.9428 ...
